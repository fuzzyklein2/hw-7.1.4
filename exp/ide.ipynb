# %%
import os
from pathlib import Path
import shutil
import subprocess

import home
from tools import *

# %%
TEST_DIR = BASE / "test"

# %%
cd("../../hw-5.1.5")
# Out:
# PosixPath('../../hw-5.1.5')

# %%
TEST_DIR.exists()
# Out:
# True
