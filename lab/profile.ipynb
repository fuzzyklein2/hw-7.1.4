# %% [markdown]
# # Profiling Program Performance

# %%
import home
# Out:
# 📁 Current working directory: /home/fuzzy/projects/C++ 2026/hello-world

# %%
# %%bash
# valgrind hello
# Out:
# ==290732== Memcheck, a memory error detector
# ==290732== Copyright (C) 2002-2022, and GNU GPL'd, by Julian Seward et al.
# ==290732== Using Valgrind-3.22.0 and LibVEX; rerun with -h for copyright info
# ==290732== Command: hello
# ==290732==
# ==290732==
# ==290732== HEAP SUMMARY:
# ==290732==     in use at exit: 0 bytes in 0 blocks
# ==290732==   total heap usage: 377 allocs, 377 frees, 186,977 bytes allocated
# ==290732==
# ==290732== All heap blocks were freed -- no leaks are possible
# ==290732==
# ==290732== For lists of detected and suppressed errors, rerun with: -s
# ==290732== ERROR SUMMARY: 0 errors from 0 contexts (suppressed: 0 from 0)
