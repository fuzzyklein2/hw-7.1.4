# %% [markdown]
# # Debug Peroxide

# %%
import gdb
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import gdb
#
# ModuleNotFoundError: No module named 'gdb'
