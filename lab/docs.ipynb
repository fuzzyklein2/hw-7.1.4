# %% [markdown]
# # Documentation
# Generate and maintain project documentation

# %%
import pyperclip

# %%
import home
# Out:
# 📁 Current working directory: /home/fuzzy/projects/C++ 2026/hello-world

# %% [markdown]
# ## doxygen

# %%
# %%bash
# rm -rf docs
# doxygen
# Out:
# Adding custom extension mapping: 'py' will be treated as language 'python'
# Doxygen version used: 1.9.8
# Notice: Output directory 'docs' does not exist. I have created it for you.
# Searching for include files...
# Searching for example files...
# Searching for images...
# Searching for dot files...
# Searching for msc files...
# Searching for dia files...
# Searching for files to exclude
# Searching INPUT for files to process...
# Searching for files in directory /home/fuzzy/projects/C++ 2026/hello-world/source
# Searching for files in directory /home/fuzzy/projects/C++ 2026/hello-world/include
# Searching for files in directory /home/fuzzy/projects/C++ 2026/hello-world/tools
# Reading and parsing tag files
# Parsing files
# Preprocessing /home/fuzzy/projects/C++ 2026/hello-world/source/config.cpp...
# Parsing file /home/fuzzy/projects/C++ 2026/hello-world/source/config.cpp...
# Preprocessing /home/fuzzy/projects/C++ 2026/hello-world/source/datetime.cpp...
# Parsing file /home/fuzzy/projects/C++ 2026/hello-world/source/datetime.cpp...
# Preprocessing /home/fuzzy/projects/C++ 2026/hello-world/source/environment.cpp...
# Parsing file /home/fuzzy/projects/C++ 2026/hello-world/source/environment.cpp...
# Preprocessing /home/fuzzy/projects/C++ 2026/hello-world/source/filter.cpp...
# Parsing file /home/fuzzy/projects/C++ 2026/hello-world/source/filter.cpp...
# Preprocessing /home/fuzzy/projects/C++ 2026/hello-world/source/fs.cpp...
# Parsing file /home/fuzzy/projects/C++ 2026/hello-world/source/fs.cpp...
# Preprocessing /home/fuzzy/projects/C++ 2026/hello-world/source/globals.cpp...
# Parsing file /home/fuzzy/projects/C++ 2026/hello-world/source/globals.cpp...
# Preprocessing /home/fuzzy/projects/C++ 2026/hello-world/source/logging.cpp...
# Parsing file /home/fuzzy/projects/C++ 2026/hello-world/source/logging.cpp...
# Preprocessing /home/fuzzy/projects/C++ 2026/hello-world/source/str.cpp...
# Parsing file /home/fuzzy/projects/C++ 2026/hello-world/source/str.cpp...
# Preprocessing /home/fuzzy/projects/C++ 2026/hello-world/include/config.hpp...
# Parsing file /home/fuzzy/projects/C++ 2026/hello-world/include/config.hpp...
# Preprocessing /home/fuzzy/projects/C++ 2026/hello-world/include/constants.hpp...
# Parsing file /home/fuzzy/projects/C++ 2026/hello-world/include/constants.hpp...
# Preprocessing /home/fuzzy/projects/C++ 2026/hello-world/include/datetime.hpp...
# Parsing file /home/fuzzy/projects/C++ 2026/hello-world/include/datetime.hpp...
# Preprocessing /home/fuzzy/projects/C++ 2026/hello-world/include/environment.hpp...
# Parsing file /home/fuzzy/projects/C++ 2026/hello-world/include/environment.hpp...
# Preprocessing /home/fuzzy/projects/C++ 2026/hello-world/include/filter.hpp...
# Parsing file /home/fuzzy/projects/C++ 2026/hello-world/include/filter.hpp...
# Preprocessing /home/fuzzy/projects/C++ 2026/hello-world/include/fs.hpp...
# Parsing file /home/fuzzy/projects/C++ 2026/hello-world/include/fs.hpp...
# Preprocessing /home/fuzzy/projects/C++ 2026/hello-world/include/globals.hpp...
# Parsing file /home/fuzzy/projects/C++ 2026/hello-world/include/globals.hpp...
# Preprocessing /home/fuzzy/projects/C++ 2026/hello-world/include/hw7.hpp...
# Parsing file /home/fuzzy/projects/C++ 2026/hello-world/include/hw7.hpp...
# Preprocessing /home/fuzzy/projects/C++ 2026/hello-world/include/logging.hpp...
# Parsing file /home/fuzzy/projects/C++ 2026/hello-world/include/logging.hpp...
# Preprocessing /home/fuzzy/projects/C++ 2026/hello-world/include/macros.h...
# Parsing file /home/fuzzy/projects/C++ 2026/hello-world/include/macros.h...
# Preprocessing /home/fuzzy/projects/C++ 2026/hello-world/include/program.hpp...
# Parsing file /home/fuzzy/projects/C++ 2026/hello-world/include/program.hpp...
# Preprocessing /home/fuzzy/projects/C++ 2026/hello-world/include/str.hpp...
# Parsing file /home/fuzzy/projects/C++ 2026/hello-world/include/str.hpp...
# Preprocessing /home/fuzzy/projects/C++ 2026/hello-world/include/sysinc.hpp...
# Parsing file /home/fuzzy/projects/C++ 2026/hello-world/include/sysinc.hpp...
# Preprocessing /home/fuzzy/projects/C++ 2026/hello-world/include/types.hpp...
# Parsing file /home/fuzzy/projects/C++ 2026/hello-world/include/types
# /home/fuzzy/projects/C++ 2026/hello-world/include/fs.hpp:32: warning: Compound FileSystem is not documented.
# /home/fuzzy/projects/C++ 2026/hello-world/include/hw7.hpp:263: warning: Compound FileSystem is not documented.
# /home/fuzzy/projects/C++ 2026/hello-world/include/filter.hpp:10: warning: Compound Filter is not documented.
# /home/fuzzy/projects/C++ 2026/hello-world/include/hw7.hpp:122: warning: Compound Filter is not documented.
# /home/fuzzy/projects/C++ 2026/hello-world/include/hw7.hpp:420: warning: Compound Program is not documented.
# /home/fuzzy/projects/C++ 2026/hello-world/include/program.hpp:13: warning: Compound Program is not documented.
# /home/fuzzy/projects/C++ 2026/hello-world/include/config.hpp:11: warning: Member configure(const Path &) (function) of file config.hpp is not documented.
# /home/fuzzy/projects/C++ 2026/hello-world/include/config.hpp:12: warning: Member load_data(const Path &p) (function) of file config.hpp is not documented.
# /home/fuzzy/projects/C++ 2026/hello-world/include/constants.hpp:16: warning: Member THIS_PATH (variable) of namespace hw7 is not documented.
# /home/fuzzy/projects/C++ 2026/hello-world/include/constants.hpp:25: warning: Member GREETING (variable) of namespace hw7 is not documented.
# /home/fuzzy/projects/C++ 2026/hello-world/include/constants.hpp:29: warning: Member EMPTY (variable) of namespace hw7 is not documented.
# /home/fuzzy/projects/C++ 2026/hello-world/include/constants.hpp:30: warning: Member DBL_SPACE (variable) of namespace hw7 is not documented.
# /home/fuzzy/projects/C++ 2026/hello-world/include/constants.hpp:31: warning: Member DOT (variable) of namespace hw7 is not documented.
# /home/fuzzy/projects/C++ 2026/hello-world/include/constants.hpp:32: warning: Member CHECK (variable) of namespace hw7 is not documented.
# /home/fuzzy/projects/C++ 2026/hello-world/include/constants.hpp:33: warning: Member EQUAL (variable) of namespace hw7 is not documented.
# /home/fuzzy/projects/C++ 2026/hello-world/include/constants.hpp:34: warning: Member UNDERSCORE (variable) of namespace hw7 is not documented.
# /home/fuzzy/projects/C++ 2026/hello-world/include/constants.hpp:35: warning: Member LEFT_BRACKET (variable) of namespace hw7 is not documented.
# /home/fuzzy/projects/C++ 2026/hello-world/include/constants.hpp:36: warning: Member RIGHT_BRACKET (variable) of namespace hw7 is not documented.
# /home/fuzzy/projects/C++ 2026/hello-world/include/constants.hpp:37: warning: Member COLON (variable) of namespace hw7 is not documented.
# /home/fuzzy/projects/C++ 2026/hello-world/include/constants.hpp:38: warning: Member QUOTE (variable) of namespace hw7 is not documented.
# /home/fuzzy/projects/C++ 2026/hello-world/include/constants.hpp:39: warning: Member DBL_QUOTE (variable) of namespace hw7 is not documented.
# /home/fuzzy/projects/C++ 2026/hello-world/include/constants.hpp:43: warning: Member CRITICAL_PICT (variable) of namespace hw7 is not documented.
# /home/fuzzy/projects/C++ 2026/hello-world/include/constants.hpp:44: warning: Member ERROR_PICT (variable) of namespace hw7 is not documented.
# /home/fuzzy/projects/C++ 2026/hello-world/include/constants.hpp:45: warning: Member WARNING_PICT (variable) of namespace hw7 is not documented.
# /home/fuzzy/projects/C++ 2026/hello-world/include/constants.hpp:46: warning: Member INFO_PICT (variable) of namespace hw7 is not documented.
# /home/fuzzy/projects/C++ 2026/hello-world/include/constants.hpp:47: warning: Member DEBUG_PICT (variable) of namespace hw7 is not documented.
# /home/fuzzy/projects/C++ 2026/hello-world/include/constants.hpp:48: warning: Member CHECK_PICT (variable) of namespace hw7 is not documented.
# /home/fuzzy/projects/C++ 2026/hello-world/include/constants.hpp:49: warning: Member FAILURE_PICT (variable) of namespace hw7 is not documented.
# /home/fuzzy/projects/C++ 2026/hello-world/include/constants.hpp:53: warning: Member VERBOSE_KEY (variable) of namespace hw7 is not documented.
# /home/fuzzy/projects/C++ 2026/hello-world/include/constants.hpp:54: warning: Member ARGS_KEY (variable) of namespace hw7 is not documented.
# /home/fuzzy/projects/C++ 2026/hello-world/include/constants.hpp:55: warning: Member VERSION_KEY (variable) of namespace hw7 is not documented.
# /home/fuzzy/projects/C++ 2026/hello-world/include/constants.hpp:59: warning: Member CONF_FILE_NAME (variable) of namespace hw7 is not documented.
# /home/fuzzy/projects/C++ 2026/hello-world/include/constants.hpp:60: warning: Member LOG_DIR_NAME (variable) of namespace hw7 is not documented.
# /home/fuzzy/projects/C++ 2026/hello-world/include/constants.hpp:61: warning: Member DATA_DIR_NAME (variable) of namespace hw7 is not documented.
# /home/fuzzy/projects/C++ 2026/hello-world/include/constants.hpp:62: warning: Member DATA_FILE_NAME (variable) of namespace hw7 is not documented.
# /home/fuzzy/projects/C++ 2026/hello-world/include/fs.hpp:15: warning: Member cwd() (function) of file fs.hpp is not documented.
# /home/fuzzy/projects/C++ 2026/hello-world/include/fs.hpp:16: warning: Member listdir(const Path &path) (function) of file fs.hpp is not documented.
# /home/fuzzy/projects/C++ 2026/hello-world/include/fs.hpp:17: warning: Member magic_type(const Path &p) (function) of file fs.hpp is not documented.
# /home/fuzzy/projects/C++ 2026/hello-world/include/fs.hpp:23: warning: Member ensure_file(const Path &p) (function) of file fs.hpp is not documented.
# /home/fuzzy/projects/C++ 2026/hello-world/include/hw7.hpp:20: warning: Member CONST (macro definition) of file hw7.hpp is not documented.
# /home/fuzzy/projects/C++ 2026/hello-world/include/hw7.hpp:21: warning: Member STATIC (macro definition) of file hw7.hpp is not documented.
# /home/fuzzy/projects/C++ 2026/hello-world/include/hw7.hpp:22: warning: Member CONSTEXPR (macro definition) of file hw7.hpp is not documented.
# /home/fuzzy/projects/C++ 2026/hello-world/include/hw7.hpp:37: warning: Member Path (typedef) of file hw7.hpp is not documented.
# /home/fuzzy/projects/C++ 2026/hello-world/include/hw7.hpp:38: warning: Member String (typedef) of file hw7.hpp is not documented.
# /home/fuzzy/projects/C++ 2026/hello-world/include/hw7.hpp:39: warning: Member StrList (typedef) of file hw7.hpp is not documented.
# /home/fuzzy/projects/C++ 2026/hello-world/include/hw7.hpp:40: warning: Member StrDict (typedef) of file hw7.hpp is not documented.
# /home/fuzzy/projects/C++ 2026/hello-world/include/hw7.hpp:41: warning: Member PathList (typedef) of file hw7.hpp is not documented.
# /home/fuzzy/projects/C++ 2026/hello-world/include/hw7.hpp:44: warning: Member JSON (typedef) of file hw7.hpp is not documented.
# /home/fuzzy/projects/C++ 2026/hello-world/include/hw7.hpp:45: warning: Member Logger (typedef) of file hw7.hpp is not documented.
# /home/fuzzy/projects/C++ 2026/hello-world/include/hw7.hpp:46: warning: Member LogLevel (typedef) of file hw7.hpp is not documented.
# /home/fuzzy/projects/C++ 2026/hello-world/include/hw7.hpp:48: warning: Member Number (typedef) of file hw7.hpp is not documented.
# /home/fuzzy/projects/C++ 2026/hello-world/include/hw7.hpp:49: warning: Member ErrCode (typedef) of file hw7.hpp is not documented.
# /home/fuzzy/projects/C++ 2026/hello-world/include/hw7.hpp:246: warning: Member cwd() (function) of file hw7.hpp is not documented.
# /home/fuzzy/projects/C++ 2026/hello-world/include/hw7.hpp:247: warning: Member listdir(const Path &path) (function) of file hw7.hpp is not documented.
# /home/fuzzy/projects/C++ 2026/hello-world/include/hw7.hpp:248: warning: Member magic_type(const Path &p) (function) of file hw7.hpp is not documented.
# /home/fuzzy/projects/C++ 2026/hello-world/include/hw7.hpp:254: warning: Member ensure_file(const Path &p) (function) of file hw7.hpp is not documented.
# /home/fuzzy/projects/C++ 2026/hello-world/include/hw7.hpp:288: warning: Member configure(const Path &) (function) of file hw7.hpp is not documented.
# /home/fuzzy/projects/C++ 2026/hello-world/include/hw7.hpp:289: warning: Member load_data(const Path &p) (function) of file hw7.hpp is not documented.
# /home/fuzzy/projects/C++ 2026/hello-world/include/environment.hpp:16: warning: argument 'config' from the argument list of check_env has multiple @param documentation sections
# /home/fuzzy/projects/C++ 2026/hello-world/include/hw7.hpp:326: warning: found documented return type for debug that does not return anything
# /home/fuzzy/projects/C++ 2026/hello-world/include/logging.hpp:34: warning: found documented return type for debug that does not return anything
# /home/fuzzy/projects/C++ 2026/hello-world/include/hw7.hpp:358: warning: argument 'directory' from the argument list of rotate_logs has multiple @param documentation sections
# /home/fuzzy/projects/C++ 2026/hello-world/include/hw7.hpp:358: warning: argument 'count' from the argument list of rotate_logs has multiple @param documentation sections
# /home/fuzzy/projects/C++ 2026/hello-world/include/macros.h:8: warning: Member CONST (macro definition) of file macros.h is not documented.
# /home/fuzzy/projects/C++ 2026/hello-world/include/macros.h:9: warning: Member STATIC (macro definition) of file macros.h is not documented.
# /home/fuzzy/projects/C++ 2026/hello-world/include/macros.h:10: warning: Member CONSTEXPR (macro definition) of file macros.h is not documented.
# /home/fuzzy/projects/C++ 2026/hello-world/include/types.hpp:21: warning: Member Path (typedef) of file types.hpp is not documented.
# /home/fuzzy/projects/C++ 2026/hello-world/include/types.hpp:22: warning: Member String (typedef) of file types.hpp is not documented.
# /home/fuzzy/projects/C++ 2026/hello-world/include/types.hpp:23: warning: Member StrList (typedef) of file types.hpp is not documented.
# /home/fuzzy/projects/C++ 2026/hello-world/include/types.hpp:24: warning: Member StrDict (typedef) of file types.hpp is not documented.
# /home/fuzzy/projects/C++ 2026/hello-world/include/types.hpp:25: warning: Member PathList (typedef) of file types.hpp is not documented.
# /home/fuzzy/projects/C++ 2026/hello-world/include/types.hpp:28: warning: Member JSON (typedef) of file types.hpp is not documented.
# /home/fuzzy/projects/C++ 2026/hello-world/include/types.hpp:29: warning: Member Logger (typedef) of file types.hpp is not documented.
# /home/fuzzy/projects/C++ 2026/hello-world/include/types.hpp:30: warning: Member LogLevel (typedef) of file types.hpp is not documented.
# /home/fuzzy/projects/C++ 2026/hello-world/include/types.hpp:32: warning: Member Number (typedef) of file types.hpp is not documented.
# /home/fuzzy/projects/C++ 2026/hello-world/include/types.hpp:33: warning: Member ErrCode (typedef) of file types.hpp is not documented.
# /home/fuzzy/projects/C++ 2026/hello-world/source/config.cpp:17: warning: Member configure(const Path &p) (function) of file config.cpp is not documented.
# /home/fuzzy/projects/C++ 2026/hello-world/source/config.cpp:45: warning: Member load_data(const Path &p) (function) of file config.cpp is not documented.
# /home/fuzzy/projects/C++ 2026/hello-world/source/fs.cpp:14: warning: Member cwd() (function) of file fs.cpp is not documented.
# /home/fuzzy/projects/C++ 2026/hello-world/source/fs.cpp:19: warning: Member listdir(const Path &path) (function) of file fs.cpp is not documented.
# /home/fuzzy/projects/C++ 2026/hello-world/source/fs.cpp:29: warning: Member magic_type(const Path &p) (function) of file fs.cpp is not documented.
# /home/fuzzy/projects/C++ 2026/hello-world/source/fs.cpp:58: warning: Member ensure_file(const Path &p) (function) of file fs.cpp is not documented.
# /home/fuzzy/projects/C++ 2026/hello-world/include/logging.hpp:34: warning: found documented return type for debug that does not return anything
# /home/fuzzy/projects/C++ 2026/hello-world/include/fs.hpp:33: warning: Member working (variable) of struct FileSystem is not documented.
# /home/fuzzy/projects/C++ 2026/hello-world/include/fs.hpp:34: warning: Member home (variable) of struct FileSystem is not documented.
# /home/fuzzy/projects/C++ 2026/hello-world/include/fs.hpp:35: warning: Member base (variable) of struct FileSystem is not documented.
# /home/fuzzy/projects/C++ 2026/hello-world/include/fs.hpp:36: warning: Member conf_dir (variable) of struct FileSystem is not documented.
# /home/fuzzy/projects/C++ 2026/hello-world/include/fs.hpp:37: warning: Member config (variable) of struct FileSystem is not documented.
# /home/fuzzy/projects/C++ 2026/hello-world/include/fs.hpp:38: warning: Member user (variable) of struct FileSystem is not documented.
# /home/fuzzy/projects/C++ 2026/hello-world/include/fs.hpp:39: warning: Member logs (variable) of struct FileSystem is not documented.
# /home/fuzzy/projects/C++ 2026/hello-world/include/fs.hpp:40: warning: Member logfile (variable) of struct FileSystem is not documented.
# /home/fuzzy/projects/C++ 2026/hello-world/include/fs.hpp:41: warning: Member data_dir (variable) of struct FileSystem is not documented.
# /home/fuzzy/projects/C++ 2026/hello-world/include/fs.hpp:42: warning: Member data (variable) of struct FileSystem is not documented.
# /home/fuzzy/projects/C++ 2026/hello-world/include/filter.hpp:49: warning: Member paths (variable) of class Filter is not documented.
# /home/fuzzy/projects/C++ 2026/hello-world/include/globals.hpp:21: warning: Member FS (variable) of struct Globals is not documented.
# /home/fuzzy/projects/C++ 2026/hello-world/include/globals.hpp:22: warning: Member config (variable) of struct Globals is not documented.
# /home/fuzzy/projects/C++ 2026/hello-world/include/globals.hpp:23: warning: Member data (variable) of struct Globals is not documented.
# /home/fuzzy/projects/C++ 2026/hello-world/include/globals.hpp:24: warning: Member _debug (variable) of struct Globals is not documented.
# /home/fuzzy/projects/C++ 2026/hello-world/include/globals.hpp:25: warning: Member verbose (variable) of struct Globals is not documented.
# /home/fuzzy/projects/C++ 2026/hello-world/include/globals.hpp:26: warning: Member version (variable) of struct Globals is not documented.
# /home/fuzzy/projects/C++ 2026/hello-world/include/globals.hpp:27: warning: Member args (variable) of struct Globals is not documented.
# /home/fuzzy/projects/C++ 2026/hello-world/include/globals.hpp:28: warning: Member input (variable) of struct Globals is not documented.
# /home/fuzzy/projects/C++ 2026/hello-world/include/hw7.hpp:382: warning: argument 'argc' of command @param is not found in the argument list of Globals::Globals(int, char **)
# /home/fuzzy/projects/C++ 2026/hello-world/include/hw7.hpp:382: warning: argument 'argv' of command @param is not found in the argument list of Globals::Globals(int, char **)
# /home/fuzzy/projects/C++ 2026/hello-world/include/hw7.hpp:425: warning: found documented return type for Program::Program that does not return anything
# /home/fuzzy/projects/C++ 2026/hello-world/include/program.hpp:18: warning: found documented return type for Program::Program that does not return anything
# /home/fuzzy/projects/C++ 2026/hello-world/include/hw7.hpp:219: warning: argument 'sep' of command @param is not found in the argument list of hw7::str::join(const StrList &L)
# /home/fuzzy/projects/C++ 2026/hello-world/include/hw7.hpp:219: warning: The following parameter of hw7::str::join(const StrList &L) is not documented:
#   parameter 'L'
# /home/fuzzy/projects/C++ 2026/hello-world/include/str.hpp:66: warning: argument 'sep' of command @param is not found in the argument list of hw7::str::join(const StrList &)
# /home/fuzzy/projects/C++ 2026/hello-world/include/hw7.hpp:234: warning: argument 'sep' of command @param is not found in the argument list of hw7::str::partition(const str &pattern)
# /home/fuzzy/projects/C++ 2026/hello-world/include/hw7.hpp:234: warning: The following parameter of hw7::str::partition(const str &pattern) is not documented:
#   parameter 'pattern'
# /home/fuzzy/projects/C++ 2026/hello-world/include/str.hpp:81: warning: argument 'sep' of command @param is not found in the argument list of hw7::str::partition(const str &pattern)
# /home/fuzzy/projects/C++ 2026/hello-world/include/str.hpp:81: warning: The following parameter of hw7::str::partition(const str &pattern) is not documented:
#   parameter 'pattern'
# /home/fuzzy/projects/C++ 2026/hello-world/include/hw7.hpp:226: warning: argument 'target' of command @param is not found in the argument list of hw7::str::replace(const str &pattern, const str &replacement)
# /home/fuzzy/projects/C++ 2026/hello-world/include/hw7.hpp:226: warning: The following parameter of hw7::str::replace(const str &pattern, const str &replacement) is not documented:
#   parameter 'pattern'
# /home/fuzzy/projects/C++ 2026/hello-world/include/str.hpp:73: warning: argument 'target' of command @param is not found in the argument list of hw7::str::replace(const str &pattern, const str &replacement)
# /home/fuzzy/projects/C++ 2026/hello-world/include/str.hpp:73: warning: The following parameter of hw7::str::replace(const str &pattern, const str &replacement) is not documented:
#   parameter 'pattern'
# /home/fuzzy/projects/C++ 2026/hello-world/include/str.hpp:60: warning: argument 'sep' of command @param is not found in the argument list of hw7::str::split(const str &)
# /home/fuzzy/projects/C++ 2026/hello-world/tools/__init__.py:15: warning: Member DATA_FILE (variable) of namespace tools is not documented.
# /home/fuzzy/projects/C++ 2026/hello-world/tools/__init__.py:17: warning: Member DATA (variable) of namespace tools is not documented.
# .hpp...
# Reading /home/fuzzy/projects/C++ 2026/hello-world/README.md...
# Reading /home/fuzzy/projects/C++ 2026/hello-world/tools/__init__.py...
# Parsing file /home/fuzzy/projects/C++ 2026/hello-world/tools/__init__.py...
# Reading /home/fuzzy/projects/C++ 2026/hello-world/tools/_git_tools.py...
# Parsing file /home/fuzzy/projects/C++ 2026/hello-world/tools/_git_tools.py...
# Reading /home/fuzzy/projects/C++ 2026/hello-world/tools/_last_saved_date.py...
# Parsing file /home/fuzzy/projects/C++ 2026/hello-world/tools/_last_saved_date.py...
# Reading /home/fuzzy/projects/C++ 2026/hello-world/tools/constants.py...
# Parsing file /home/fuzzy/projects/C++ 2026/hello-world/tools/constants.py...
# Reading /home/fuzzy/projects/C++ 2026/hello-world/tools/nbtools.py...
# Parsing file /home/fuzzy/projects/C++ 2026/hello-world/tools/nbtools.py...
# Reading /home/fuzzy/projects/C++ 2026/hello-world/tools/picts.py...
# Parsing file /home/fuzzy/projects/C++ 2026/hello-world/tools/picts.py...
# Reading /home/fuzzy/projects/C++ 2026/hello-world/tools/read_lines.py...
# Parsing file /home/fuzzy/projects/C++ 2026/hello-world/tools/read_lines.py...
# Building macro definition list...
# Building group list...
# Building directory list...
# Building namespace list...
# Building file list...
# Building class list...
# Building concept list...
# Computing nesting relations for classes...
# Associating documentation with classes...
# Associating documentation with concepts...
# Associating documentation with modules...
# Building example list...
# Searching for enumerations...
# Searching for documented typedefs...
# Searching for members imported via using declarations...
# Searching for included using directives...
# Searching for documented variables...
# Building interface member list...
# Building member list...
# Searching for friends...
# Searching for documented defines...
# Computing class inheritance relations...
# Computing class usage relations...
# Flushing cached template relations that have become invalid...
# Computing class relations...
# Add enum values to enums...
# Searching for member function documentation...
# Creating members for template instances...
# Building page list...
# Search for main page...
# Computing page relations...
# Determining the scope of groups...
# Computing module relations...
# Sorting lists...
# Determining which enums are documented
# Computing member relations...
# Building full member lists recursively...
# Adding members to member groups.
# Computing member references...
# Inheriting documentation...
# Generating disk names...
# Adding source references...
# Adding xrefitems...
# Sorting member lists...
# Setting anonymous enum type...
# Computing dependencies between directories...
# Generating citations page...
# Counting members...
# Counting data structures...
# Resolving user defined references...
# Finding anchors and sections in the documentation...
# Transferring function references...
# Combining using relations...
# Adding members to index pages...
# Correcting members for VHDL...
# Computing tooltip texts...
# Generating style sheet...
# Generating search indices...
# Generating example documentation...
# Generating file sources...
# Generating code for file include/config.hpp...
# Generating code for file include/constants.hpp...
# Generating code for file include/datetime.hpp...
# Generating code for file include/environment.hpp...
# Generating code for file include/filter.hpp...
# Generating code for file include/fs.hpp...
# Generating code for file include/globals.hpp...
# Generating code for file include/hw7.hpp...
# Generating code for file include/logging.hpp...
# Generating code for file include/macros.h...
# Generating code for file include/program.hpp...
# Generating code for file include/str.hpp...
# Generating code for file include/sysinc.hpp...
# Generating code for file include/types.hpp...
# Generating file documentation...
# Generating docs for file include/config.hpp...
# Generating docs for file include/constants.hpp...
# Generating docs for file include/datetime.hpp...
# Generating docs for file include/environment.hpp...
# Generating docs for file include/filter.hpp...
# Generating docs for file include/fs.hpp...
# Generating docs for file include/globals.hpp...
# Generating docs for file include/hw7.hpp...
# Generating docs for file include/logging.hpp...
# Generating docs for file include/macros.h...
# Generating docs for file include/program.hpp...
# Generating docs for file include/str.hpp...
# Generating docs for file include/sysinc.hpp...
# Generating docs for file include/types.hpp...
# Generating docs for file source/config.cpp...
# Generating docs for file source/datetime.cpp...
# Generating docs for file source/environment.cpp...
# Generating docs for file source/filter.cpp...
# Generating docs for file source/fs.cpp...
# Generating docs for file source/globals.cpp...
# Generating docs for file source/logging.cpp...
# Generating docs for file source/str.cpp...
# Generating page documentation...
# Generating docs for page todo...
# Generating docs for page bug...
# Generating group documentation...
# Generating class documentation...
# Generating docs for compound FileSystem...
# Generating docs for compound Filter...
# Generating docs for compound Globals...
# Generating docs for compound Program...
# Generating concept documentation...
# Generating module documentation...
# Generating namespace documentation...
# Generating docs for compound hw7::str...
# Generating docs for namespace tools
# Generating graph info page...
# Generating directory documentation...
# Generating dependency graph for directory source
# Generating index page...
# Generating main page...
# Generating page index...
# Generating topic index...
# Generating module index...
# Generating module member index...
# Generating namespace index...
# Generating namespace member index...
# Generating concept index...
# Generating annotated compound index...
# Generating alphabetical compound index...
# Generating hierarchical class index...
# Generating graphical class hierarchy...
# Generating member index...
# Generating file index...
# Generating file member index...
# Generating example index...
# finalizing index lists...
# writing tag file...
# Running plantuml with JAVA...
# Running dot...
# Generating dot graphs using 5 parallel threads...
# Running dot for graph 1/45
# Running dot for graph 2/45
# Running dot for graph 3/45
# Running dot for graph 4/45
# Running dot for graph 5/45
# Running dot for graph 6/45
# Running dot for graph 7/45
# Running dot for graph 8/45
# Running dot for graph 9/45
# Running dot for graph 10/45
# Running dot for graph 11/45
# Running dot for graph 12/45
# Running dot for graph 13/45
# Running dot for graph 14/45
# Running dot for graph 15/45
# Running dot for graph 16/45
# Running dot for graph 17/45
# Running dot for graph 18/45
# Running dot for graph 19/45
# Running dot for graph 20/45
# Running dot for graph 21/45
# Running dot for graph 22/45
# Running dot for graph 23/45
# Running dot for graph 24/45
# Running dot for graph 25/45
# Running dot for graph 26/45
# Running dot for graph 27/45
# Running dot for graph 28/45
# Running dot for graph 29/45
# Running dot for graph 30/45
# Running dot for graph 31/45
# Running dot for graph 32/45
# Running dot for graph 33/45
# Running dot for graph 34/45
# Running dot for graph 35/45
# Running dot for graph 36/45
# Running dot for graph 37/45
# Running dot for graph 38/45
# Running dot for graph 39/45
# Running dot for graph 40/45
# Running dot for graph 41/45
# Running dot for graph 42/45
# Running dot for graph 43/45
# Running dot for graph 44/45
# Running dot for graph 45/45
# Patching output file 1/27
# Patching output file 2/27
# Patching output file 3/27
# Patching output file 4/27
# Patching output file 5/27
# Patching output file 6/27
# Patching output file 7/27
# Patching output file 8/27
# Patching output file 9/27
# Patching output file 10/27
# Patching output file 11/27
# Patching output file 12/27
# Patching output file 13/27
# Patching output file 14/27
# Patching output file 15/27
# Patching output file 16/27
# Patching output file 17/27
# Patching output file 18/27
# Patching output file 19/27
# Patching output file 20/27
# Patching output file 21/27
# Patching output file 22/27
# Patching output file 23/27
# Patching output file 24/27
# Patching output file 25/27
# Patching output file 26/27
# Patching output file 27/27
# type lookup cache used 254/65536 hits=1435 misses=280
# symbol lookup cache used 214/65536 hits=1166 misses=214
# finished...

# %% [markdown]
# [DOCS](docs/html/index.html)

# %% [markdown]
# ## Make a docstring

# %%
def doxify(text):
    # Just add comment delimiters and asterisks.
    lines = text.split('\n')[1:]
    result = ['/**']
    result.extend([' * ' + s for s in lines])
    result.append(' */')
    return '\n'.join(result)

# %%
s = (doxify("""
Process paths.



@param target The substring to find and replace.
@param replacement String to replace the target with.
@return Copy of `this` with all occurences of `target` replaced by `replacement`."""))
print(s)
pyperclip.copy(s)
print("Docstring copied to clipboard")
# Out:
# /**
#  * Process paths.
#  *
#  * ## File Types
#  *
#  * ### Directory
#  *
#  * ### Text
#  *
#  *     * `.txt`
#  *
#  * #### Headers
#  *
#  *     * `.h`
#  *     * `.hpp`
#  *
#  * #### Source Code
#  *
#  *     * `.c`
#  *     * `.cpp`
#  *     * `.js`
#  *     * `.py`
#  *     * `.sh`
#  *
#  * #### HTML
#  *
#  *     * `.htm`
#  *     * `.html`
#  *
#  * #### Configuration
#  *
#  *     * `.cfg`
#  *
#  * #### CSV
#  *
#  *     * `.csv`
#  *
#  * #### Data
#  *
#  *     * `.json`
#  *
#  * #### Logs
#  *
#  *     * `.log`
#  *
#  * #### Stylesheets
#  *
#  *     * `.css`
#  *
#  * #### CGI
#  *
#  *     * `.cgi`
#  *
#  * ### Binary
#  *
#  * #### Executables
#  *
#  * #### Archives
#  *
#  *     * `.deb`
#  *     * `.pkl`
#  *     * `.tar.gz`
#  *     * `.zip`
#  *
#  * #### Graphics
#  *
#  *     * `.gif`
#  *     * `.jpeg`
#  *     * `.png`
#  *
#  * #### Audio
#  *
#  *     * `.flac`
#  *     * `.mp3`
#  *
#  * #### Video
#  *
#  *     * `.mp4`
#  *
#  * ### Databases
#  *
#  *     * `.db`
#  *
#  * ### FIFO
#  *
#  * ### Links
#  *
#  * #### Hard
#  * #### Symbolic
#  *
#  *
#  * @param target The substring to find and replace.
#  * @param replacement String to replace the target with.
#  * @return Copy of `this` with all occurences of `target` replaced by `replacement`.
#  */
# Docstring copied to clipboard

# %%
help(str.replace)
# Out:
# Help on method descriptor replace:
#
# replace(self, old, new, /, count=-1) unbound builtins.str method
#     Return a copy with all occurrences of substring old replaced by new.
#
#       count
#         Maximum number of occurrences to replace.
#         -1 (the default value) means replace all occurrences.
#
#     If the optional argument count is given, only the first count occurrences are
#     replaced.

# %% [markdown]
# ## Configuration

# %% [markdown]
# ### Default Settings

# %%
DOXYFILE = Path("contrib/Doxyfile")
text = [s for s in DOXYFILE.read_text().split('\n') if not (s.startswith('#') or s == "")]
print('\n'.join(text))
# Out:
# DOXYFILE_ENCODING      = UTF-8
# PROJECT_NAME           = "My Project"
# PROJECT_NUMBER         =
# PROJECT_BRIEF          =
# PROJECT_LOGO           =
# OUTPUT_DIRECTORY       =
# CREATE_SUBDIRS         = NO
# CREATE_SUBDIRS_LEVEL   = 8
# ALLOW_UNICODE_NAMES    = NO
# OUTPUT_LANGUAGE        = English
# BRIEF_MEMBER_DESC      = YES
# REPEAT_BRIEF           = YES
# ABBREVIATE_BRIEF       = "The $name class" \
#                          "The $name widget" \
#                          "The $name file" \
#                          is \
#                          provides \
#                          specifies \
#                          contains \
#                          represents \
#                          a \
#                          an \
#                          the
# ALWAYS_DETAILED_SEC    = NO
# INLINE_INHERITED_MEMB  = NO
# FULL_PATH_NAMES        = YES
# STRIP_FROM_PATH        =
# STRIP_FROM_INC_PATH    =
# SHORT_NAMES            = NO
# JAVADOC_AUTOBRIEF      = NO
# JAVADOC_BANNER         = NO
# QT_AUTOBRIEF           = NO
# MULTILINE_CPP_IS_BRIEF = NO
# PYTHON_DOCSTRING       = YES
# INHERIT_DOCS           = YES
# SEPARATE_MEMBER_PAGES  = NO
# TAB_SIZE               = 4
# ALIASES                =
# OPTIMIZE_OUTPUT_FOR_C  = NO
# OPTIMIZE_OUTPUT_JAVA   = NO
# OPTIMIZE_FOR_FORTRAN   = NO
# OPTIMIZE_OUTPUT_VHDL   = NO
# OPTIMIZE_OUTPUT_SLICE  = NO
# EXTENSION_MAPPING      =
# MARKDOWN_SUPPORT       = YES
# TOC_INCLUDE_HEADINGS   = 5
# MARKDOWN_ID_STYLE      = DOXYGEN
# AUTOLINK_SUPPORT       = YES
# BUILTIN_STL_SUPPORT    = NO
# CPP_CLI_SUPPORT        = NO
# SIP_SUPPORT            = NO
# IDL_PROPERTY_SUPPORT   = YES
# DISTRIBUTE_GROUP_DOC   = NO
# GROUP_NESTED_COMPOUNDS = NO
# SUBGROUPING            = YES
# INLINE_GROUPED_CLASSES = NO
# INLINE_SIMPLE_STRUCTS  = NO
# TYPEDEF_HIDES_STRUCT   = NO
# LOOKUP_CACHE_SIZE      = 0
# NUM_PROC_THREADS       = 1
# TIMESTAMP              = NO
# EXTRACT_ALL            = NO
# EXTRACT_PRIVATE        = NO
# EXTRACT_PRIV_VIRTUAL   = NO
# EXTRACT_PACKAGE        = NO
# EXTRACT_STATIC         = NO
# EXTRACT_LOCAL_CLASSES  = YES
# EXTRACT_LOCAL_METHODS  = NO
# EXTRACT_ANON_NSPACES   = NO
# RESOLVE_UNNAMED_PARAMS = YES
# HIDE_UNDOC_MEMBERS     = NO
# HIDE_UNDOC_CLASSES     = NO
# HIDE_FRIEND_COMPOUNDS  = NO
# HIDE_IN_BODY_DOCS      = NO
# INTERNAL_DOCS          = NO
# CASE_SENSE_NAMES       = SYSTEM
# HIDE_SCOPE_NAMES       = NO
# HIDE_COMPOUND_REFERENCE= NO
# SHOW_HEADERFILE        = YES
# SHOW_INCLUDE_FILES     = YES
# SHOW_GROUPED_MEMB_INC  = NO
# FORCE_LOCAL_INCLUDES   = NO
# INLINE_INFO            = YES
# SORT_MEMBER_DOCS       = YES
# SORT_BRIEF_DOCS        = NO
# SORT_MEMBERS_CTORS_1ST = NO
# SORT_GROUP_NAMES       = NO
# SORT_BY_SCOPE_NAME     = NO
# STRICT_PROTO_MATCHING  = NO
# GENERATE_TODOLIST      = YES
# GENERATE_TESTLIST      = YES
# GENERATE_BUGLIST       = YES
# GENERATE_DEPRECATEDLIST= YES
# ENABLED_SECTIONS       =
# MAX_INITIALIZER_LINES  = 30
# SHOW_USED_FILES        = YES
# SHOW_FILES             = YES
# SHOW_NAMESPACES        = YES
# FILE_VERSION_FILTER    =
# LAYOUT_FILE            =
# CITE_BIB_FILES         =
# QUIET                  = NO
# WARNINGS               = YES
# WARN_IF_UNDOCUMENTED   = YES
# WARN_IF_DOC_ERROR      = YES
# WARN_IF_INCOMPLETE_DOC = YES
# WARN_NO_PARAMDOC       = NO
# WARN_IF_UNDOC_ENUM_VAL = NO
# WARN_AS_ERROR          = NO
# WARN_FORMAT            = "$file:$line: $text"
# WARN_LINE_FORMAT       = "at line $line of file $file"
# WARN_LOGFILE           =
# INPUT                  =
# INPUT_ENCODING         = UTF-8
# INPUT_FILE_ENCODING    =
# FILE_PATTERNS          = *.c \
#                          *.cc \
#                          *.cxx \
#                          *.cxxm \
#                          *.cpp \
#                          *.cppm \
#                          *.c++ \
#                          *.c++m \
#                          *.java \
#                          *.ii \
#                          *.ixx \
#                          *.ipp \
#                          *.i++ \
#                          *.inl \
#                          *.idl \
#                          *.ddl \
#                          *.odl \
#                          *.h \
#                          *.hh \
#                          *.hxx \
#                          *.hpp \
#                          *.h++ \
#                          *.ixx \
#                          *.l \
#                          *.cs \
#                          *.d \
#                          *.php \
#                          *.php4 \
#                          *.php5 \
#                          *.phtml \
#                          *.inc \
#                          *.m \
#                          *.markdown \
#                          *.md \
#                          *.mm \
#                          *.dox \
#                          *.py \
#                          *.pyw \
#                          *.f90 \
#                          *.f95 \
#                          *.f03 \
#                          *.f08 \
#                          *.f18 \
#                          *.f \
#                          *.for \
#                          *.vhd \
#                          *.vhdl \
#                          *.ucf \
#                          *.qsf \
#                          *.ice
# RECURSIVE              = NO
# EXCLUDE                =
# EXCLUDE_SYMLINKS       = NO
# EXCLUDE_PATTERNS       =
# EXCLUDE_SYMBOLS        =
# EXAMPLE_PATH           =
# EXAMPLE_PATTERNS       = *
# EXAMPLE_RECURSIVE      = NO
# IMAGE_PATH             =
# INPUT_FILTER           =
# FILTER_PATTERNS        =
# FILTER_SOURCE_FILES    = NO
# FILTER_SOURCE_PATTERNS =
# USE_MDFILE_AS_MAINPAGE =
# FORTRAN_COMMENT_AFTER  = 72
# SOURCE_BROWSER         = NO
# INLINE_SOURCES         = NO
# STRIP_CODE_COMMENTS    = YES
# REFERENCED_BY_RELATION = NO
# REFERENCES_RELATION    = NO
# REFERENCES_LINK_SOURCE = YES
# SOURCE_TOOLTIPS        = YES
# USE_HTAGS              = NO
# VERBATIM_HEADERS       = YES
# CLANG_ASSISTED_PARSING = NO
# CLANG_ADD_INC_PATHS    = YES
# CLANG_OPTIONS          =
# CLANG_DATABASE_PATH    =
# ALPHABETICAL_INDEX     = YES
# IGNORE_PREFIX          =
# GENERATE_HTML          = YES
# HTML_OUTPUT            = html
# HTML_FILE_EXTENSION    = .html
# HTML_HEADER            =
# HTML_FOOTER            =
# HTML_STYLESHEET        =
# HTML_EXTRA_STYLESHEET  =
# HTML_EXTRA_FILES       =
# HTML_COLORSTYLE        = AUTO_LIGHT
# HTML_COLORSTYLE_HUE    = 220
# HTML_COLORSTYLE_SAT    = 100
# HTML_COLORSTYLE_GAMMA  = 80
# HTML_DYNAMIC_MENUS     = YES
# HTML_DYNAMIC_SECTIONS  = NO
# HTML_CODE_FOLDING      = YES
# HTML_INDEX_NUM_ENTRIES = 100
# GENERATE_DOCSET        = NO
# DOCSET_FEEDNAME        = "Doxygen generated docs"
# DOCSET_FEEDURL         =
# DOCSET_BUNDLE_ID       = org.doxygen.Project
# DOCSET_PUBLISHER_ID    = org.doxygen.Publisher
# DOCSET_PUBLISHER_NAME  = Publisher
# GENERATE_HTMLHELP      = NO
# CHM_FILE               =
# HHC_LOCATION           =
# GENERATE_CHI           = NO
# CHM_INDEX_ENCODING     =
# BINARY_TOC             = NO
# TOC_EXPAND             = NO
# SITEMAP_URL            =
# GENERATE_QHP           = NO
# QCH_FILE               =
# QHP_NAMESPACE          = org.doxygen.Project
# QHP_VIRTUAL_FOLDER     = doc
# QHP_CUST_FILTER_NAME   =
# QHP_CUST_FILTER_ATTRS  =
# QHP_SECT_FILTER_ATTRS  =
# QHG_LOCATION           =
# GENERATE_ECLIPSEHELP   = NO
# ECLIPSE_DOC_ID         = org.doxygen.Project
# DISABLE_INDEX          = NO
# GENERATE_TREEVIEW      = NO
# FULL_SIDEBAR           = NO
# ENUM_VALUES_PER_LINE   = 4
# TREEVIEW_WIDTH         = 250
# EXT_LINKS_IN_WINDOW    = NO
# OBFUSCATE_EMAILS       = YES
# HTML_FORMULA_FORMAT    = png
# FORMULA_FONTSIZE       = 10
# FORMULA_MACROFILE      =
# USE_MATHJAX            = NO
# MATHJAX_VERSION        = MathJax_2
# MATHJAX_FORMAT         = HTML-CSS
# MATHJAX_RELPATH        =
# MATHJAX_EXTENSIONS     =
# MATHJAX_CODEFILE       =
# SEARCHENGINE           = YES
# SERVER_BASED_SEARCH    = NO
# EXTERNAL_SEARCH        = NO
# SEARCHENGINE_URL       =
# SEARCHDATA_FILE        = searchdata.xml
# EXTERNAL_SEARCH_ID     =
# EXTRA_SEARCH_MAPPINGS  =
# GENERATE_LATEX         = YES
# LATEX_OUTPUT           = latex
# LATEX_CMD_NAME         =
# MAKEINDEX_CMD_NAME     = makeindex
# LATEX_MAKEINDEX_CMD    = makeindex
# COMPACT_LATEX          = NO
# PAPER_TYPE             = a4
# EXTRA_PACKAGES         =
# LATEX_HEADER           =
# LATEX_FOOTER           =
# LATEX_EXTRA_STYLESHEET =
# LATEX_EXTRA_FILES      =
# PDF_HYPERLINKS         = YES
# USE_PDFLATEX           = YES
# LATEX_BATCHMODE        = NO
# LATEX_HIDE_INDICES     = NO
# LATEX_BIB_STYLE        = plain
# LATEX_EMOJI_DIRECTORY  =
# GENERATE_RTF           = NO
# RTF_OUTPUT             = rtf
# COMPACT_RTF            = NO
# RTF_HYPERLINKS         = NO
# RTF_STYLESHEET_FILE    =
# RTF_EXTENSIONS_FILE    =
# GENERATE_MAN           = NO
# MAN_OUTPUT             = man
# MAN_EXTENSION          = .3
# MAN_SUBDIR             =
# MAN_LINKS              = NO
# GENERATE_XML           = NO
# XML_OUTPUT             = xml
# XML_PROGRAMLISTING     = YES
# XML_NS_MEMB_FILE_SCOPE = NO
# GENERATE_DOCBOOK       = NO
# DOCBOOK_OUTPUT         = docbook
# GENERATE_AUTOGEN_DEF   = NO
# GENERATE_SQLITE3       = NO
# SQLITE3_OUTPUT         = sqlite3
# SQLITE3_RECREATE_DB    = YES
# GENERATE_PERLMOD       = NO
# PERLMOD_LATEX          = NO
# PERLMOD_PRETTY         = YES
# PERLMOD_MAKEVAR_PREFIX =
# ENABLE_PREPROCESSING   = YES
# MACRO_EXPANSION        = NO
# EXPAND_ONLY_PREDEF     = NO
# SEARCH_INCLUDES        = YES
# INCLUDE_PATH           =
# INCLUDE_FILE_PATTERNS  =
# PREDEFINED             =
# EXPAND_AS_DEFINED      =
# SKIP_FUNCTION_MACROS   = YES
# TAGFILES               =
# GENERATE_TAGFILE       =
# ALLEXTERNALS           = NO
# EXTERNAL_GROUPS        = YES
# EXTERNAL_PAGES         = YES
# HIDE_UNDOC_RELATIONS   = YES
# HAVE_DOT               = YES
# DOT_NUM_THREADS        = 0
# DOT_COMMON_ATTR        = "fontname=Helvetica,fontsize=10"
# DOT_EDGE_ATTR          = "labelfontname=Helvetica,labelfontsize=10"
# DOT_NODE_ATTR          = "shape=box,height=0.2,width=0.4"
# DOT_FONTPATH           =
# CLASS_GRAPH            = YES
# COLLABORATION_GRAPH    = YES
# GROUP_GRAPHS           = YES
# UML_LOOK               = NO
# UML_LIMIT_NUM_FIELDS   = 10
# DOT_UML_DETAILS        = NO
# DOT_WRAP_THRESHOLD     = 17
# TEMPLATE_RELATIONS     = NO
# INCLUDE_GRAPH          = YES
# INCLUDED_BY_GRAPH      = YES
# CALL_GRAPH             = NO
# CALLER_GRAPH           = NO
# GRAPHICAL_HIERARCHY    = YES
# DIRECTORY_GRAPH        = YES
# DIR_GRAPH_MAX_DEPTH    = 1
# DOT_IMAGE_FORMAT       = png
# INTERACTIVE_SVG        = NO
# DOT_PATH               =
# DOTFILE_DIRS           =
# DIA_PATH               =
# DIAFILE_DIRS           =
# PLANTUML_JAR_PATH      =
# PLANTUML_CFG_FILE      =
# PLANTUML_INCLUDE_PATH  =
# DOT_GRAPH_MAX_NODES    = 50
# MAX_DOT_GRAPH_DEPTH    = 0
# DOT_MULTI_TARGETS      = NO
# GENERATE_LEGEND        = YES
# DOT_CLEANUP            = YES
# MSCGEN_TOOL            =
# MSCFILE_DIRS           =

# %% [markdown]
# I edited these by hand the last time I did it, and it's relatively simple compared to the time and effort involved with scripting it.

# %%
USER_DOXYFILE = Path("Doxyfile")
USER_DOXYFILE.write_text('\n'.join(text))
# Out:
# 10391

# %% [markdown]
# [DOCS](http://localhost:8000/docs/html/)
