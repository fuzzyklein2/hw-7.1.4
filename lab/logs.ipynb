# %% [markdown]
# # Logging
# Send log output to the console and a logfile

# %%
import json
import os
from pathlib import Path

# %%
import home

# %% [markdown]
# ## View the latest log file

# %%
DATA_FILE = "data/peroxide.json"
with Path(DATA_FILE).open() as f:
    DATA = json.load(f)
PROGRAM = DATA["program"]
logs = Path.home() / f".log/{PROGRAM}"
files = sorted(os.listdir(logs))
f = Path(logs) / files[-1]
print(f"File: {f}")
print()
print(f.read_text())
# Out:
# File: /home/fuzzy/.log/peroxide/2026-08-30_13-30-15.log

# %% [markdown]
# ## View the `meson` log

# %%
MESON_LOG = Path("build/meson-logs/meson-log.txt")

# %%
print(MESON_LOG.read_text())
# Out:
# Build started at 2026-08-26T12:48:31.975661
# Main binary: /usr/bin/python3
# Build Options:
# Python system: Linux
# The Meson build system
# Version: 1.3.2
# Source dir: /home/fuzzy/projects/C++ 2026/hello-world
# Build dir: /home/fuzzy/projects/C++ 2026/hello-world/build
# Build type: native build
# Project name: hello7
# Project version: 1.0
# C++ compiler for the host machine: c++ (gcc 13.3.0 "c++ (Ubuntu 13.3.0-6ubuntu2~24.04.1) 13.3.0")
# C++ linker for the host machine: c++ ld.bfd 2.42
# -----------
# Detecting archiver via: `gcc-ar --version` -> 0
# stdout:
# GNU ar (GNU Binutils for Ubuntu) 2.42
# Copyright (C) 2024 Free Software Foundation, Inc.
# This program is free software; you may redistribute it under the terms of
# the GNU General Public License version 3 or (at your option) any later version.
# This program has absolutely no warranty.
# -----------
# C++ compiler for the build machine: c++ (gcc 13.3.0 "c++ (Ubuntu 13.3.0-6ubuntu2~24.04.1) 13.3.0")
# ...

# %% [markdown]
# ## View the `git` log

# %%
# %%bash
# git log --oneline --graph --decorate -20
# Out:
# *   57751fb (HEAD -> main, origin/main) More bullshit.
# |\
# | *   8a4032f Merge pull request #2 from fuzzyklein2/point
# | |\
# | | * f1b7afd (origin/point) Modify pattern constructor and load method
# | | * 4b3d0db Clean up player.cpp by removing comments
# | | * fe325b2 Enhance documentation for clip methods in song.hpp
# | | * 5ee1250 Comment out 'song' class declaration
# | | * 8a5ea57 Modify pattern constructor and enhance comments
# | | * ba61c04 Change Peroxide class inheritance to public
# | | * d0aadc9 Change ProgPtr type from Peroxide to Program
# | | * 08f0275 Add ProgPtr type alias and fix Vector alias
# | | * 16f591d Fix type name from 'peroxide' to 'Peroxide'
# | | * 6c08754 Fix casing of Peroxide in unique_ptr declaration
# | | * b7eb54c Refactor main function to use unique_ptr for Peroxide
# | | * d88bd22 Change program pointer to unique_ptr
# | | * 67dfe76 Add program pointer to globals
# | | * 8d9e9df Add program variable and ensure repeat is external
# ...

# %%
# %%bash
# git log --oneline --graph --decorate -20
# Out:
# *   57751fb (HEAD -> main, origin/main) More bullshit.
# |\
# | *   8a4032f Merge pull request #2 from fuzzyklein2/point
# | |\
# | | * f1b7afd (origin/point) Modify pattern constructor and load method
# | | * 4b3d0db Clean up player.cpp by removing comments
# | | * fe325b2 Enhance documentation for clip methods in song.hpp
# | | * 5ee1250 Comment out 'song' class declaration
# | | * 8a5ea57 Modify pattern constructor and enhance comments
# | | * ba61c04 Change Peroxide class inheritance to public
# | | * d0aadc9 Change ProgPtr type from Peroxide to Program
# | | * 08f0275 Add ProgPtr type alias and fix Vector alias
# | | * 16f591d Fix type name from 'peroxide' to 'Peroxide'
# | | * 6c08754 Fix casing of Peroxide in unique_ptr declaration
# | | * b7eb54c Refactor main function to use unique_ptr for Peroxide
# | | * d88bd22 Change program pointer to unique_ptr
# | | * 67dfe76 Add program pointer to globals
# | | * 8d9e9df Add program variable and ensure repeat is external
# ...
