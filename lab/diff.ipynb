# %% [markdown]
# # Diff
# Find the differences between files.

# %%
from difflib import HtmlDiff
from pathlib import Path

# %%
from IPython.display import display, HTML

# %%
from tools._read_lines import read_lines
# Out:
# Initializing tools...
# Current working directory: /home/fuzzy/projects/C++ 2026/hello-world
# {'author': 'Russell Alan Klein',
#  'copyright': '2026',
#  'description': 'Simple C++ CLI app framework.',
#  'help': {'args': 'Files to process.',
#           'debug': 'Debugging mode.',
#           'verbose': 'Extra output.',
#           'version': 'Display program version.'},
#  'license': 'MIT',
#  'program': 'hello',
#  'version': '0.0.0'}

# %%
import home

# %%
WORKING = Path.home() / 'projects/hw-1.2.0'
f1 = WORKING / 'pyproject-2.0.toml'
f2 = WORKING / 'pyproject.toml'
L1 = read_lines(WORKING / 'pyproject-2.0.toml')
L2 = read_lines(WORKING / 'pyproject.toml')

# %%
display(HTML(HtmlDiff().make_table(L1, L2, fromdesc=f1.name,  todesc=f2.name)))
# Out:
#     <table class="diff" id="difflib_chg_to4__top"
#            cellspacing="0" cellpadding="0" rules="groups" >
#         <colgroup></colgroup> <colgroup></colgroup> <colgroup></colgroup>
#         <colgroup></colgroup> <colgroup></colgroup> <colgroup></colgroup>
#         <thead><tr><th class="diff_next"><br /></th><th colspan="2" class="diff_header">pyproject-2.0.toml</th><th class="diff_next"><br /></th><th colspan="2" class="diff_header">pyproject.toml</th></tr></thead>
#         <tbody>
#             <tr><td class="diff_next" id="difflib_chg_to4__0"><a href="#difflib_chg_to4__0">f</a></td><td class="diff_header" id="from4_1">1</td><td nowrap="nowrap">#&nbsp;pyproject.toml</td><td class="diff_next"><a href="#difflib_chg_to4__0">f</a></td><td class="diff_header" id="to4_1">1</td><td nowrap="nowrap">#&nbsp;pyproject.toml</td></tr>
#             <tr><td class="diff_next"><a href="#difflib_chg_to4__1">n</a></td><td class="diff_header" id="from4_2">2</td><td nowrap="nowrap">#&nbsp;===============================================</td><td class="diff_next"><a href="#difflib_chg_to4__1">n</a></td><td class="diff_header" id="to4_2">2</td><td nowrap="nowrap">#&nbsp;===============================================<span class="diff_add">=======</span></td></tr>
#             <tr><td class="diff_next"></td><td class="diff_header" id="from4_3">3</td><td nowrap="nowrap"><span class="diff_sub">#&nbsp;Modern&nbsp;setuptools-based&nbsp;project&nbsp;template</span></td><td class="diff_next"></td><td class="diff_header" id="to4_3">3</td><td nowrap="nowrap"><span class="diff_add">#&nbsp;PURE&nbsp;DECLARATIVE&nbsp;PYPROJECT&nbsp;TEMPLATE&nbsp;(no&nbsp;setup.py)</span></td></tr>
#             <tr><td class="diff_next"></td><td class="diff_header" id="from4_4">4</td><td nowrap="nowrap">#&nbsp;-----------------------------------------------</td><td class="diff_next"></td><td class="diff_header" id="to4_4">4</td><td nowrap="nowrap">#&nbsp;-----------------------------------------------<span class="diff_add">-------</span></td></tr>
#             <tr><td class="diff_next"></td><td class="diff_header" id="from4_5">5</td><td nowrap="nowrap"><span class="diff_sub">#&nbsp;Replace&nbsp;fields&nbsp;marked&nbsp;with&nbsp;"CHANGE&nbsp;ME"&nbsp;before&nbsp;use</span></td><td class="diff_next"></td><td class="diff_header" id="to4_5">5</td><td nowrap="nowrap"><span class="diff_add">#&nbsp;Uses&nbsp;setuptools&nbsp;as&nbsp;the&nbsp;build&nbsp;backend,&nbsp;but&nbsp;configures</span></td></tr>
#             <tr><td class="diff_next"></td><td class="diff_header"></td><td nowrap="nowrap"></td><td class="diff_next"></td><td class="diff_header" id="to4_6">6</td><td nowrap="nowrap"><span class="diff_add">#&nbsp;everything&nbsp;directly&nbsp;here.</span></td></tr>
#             <tr><td class="diff_next"></td><td class="diff_header" id="from4_6">6</td><td nowrap="nowrap">#&nbsp;===============================================</td><td class="diff_next"></td><td class="diff_header" id="to4_7">7</td><td nowrap="nowrap">#&nbsp;===============================================<span class="diff_add">=======</span></td></tr>
#             <tr><td class="diff_next"></td><td class="diff_header" id="from4_7">7</td><td nowrap="nowrap"></td><td class="diff_next"></td><td class="diff_header" id="to4_8">8</td><td nowrap="nowrap"></td></tr>
#             <tr><td class="diff_next" id="difflib_chg_to4__1"></td><td class="diff_header" id="from4_8">8</td><td nowrap="nowrap">[build-system]</td><td class="diff_next"></td><td class="diff_header" id="to4_9">9</td><td nowrap="nowrap">[build-system]</td></tr>
#             <tr><td class="diff_next"></td><td class="diff_header" id="from4_9">9</td><td nowrap="nowrap">requires&nbsp;=&nbsp;["setuptools&gt;=75",&nbsp;"wheel"]</td><td class="diff_next"></td><td class="diff_header" id="to4_10">10</td><td nowrap="nowrap">requires&nbsp;=&nbsp;["setuptools&gt;=75",&nbsp;"wheel"]</td></tr>
#             <tr><td class="diff_next"></td><td class="diff_header" id="from4_10">10</td><td nowrap="nowrap">build-backend&nbsp;=&nbsp;"setuptools.build_meta"</td><td class="diff_next"></td><td class="diff_header" id="to4_11">11</td><td nowrap="nowrap">build-backend&nbsp;=&nbsp;"setuptools.build_meta"</td></tr>
#             <tr><td class="diff_next"></td><td class="diff_header" id="from4_11">11</td><td nowrap="nowrap"></td><td class="diff_next"></td><td class="diff_header" id="to4_12">12</td><td nowrap="nowrap"></td></tr>
#             <tr><td class="diff_next"></td><td class="diff_header" id="from4_12">12</td><td nowrap="nowrap">[project]</td><td class="diff_next"></td><td class="diff_header" id="to4_13">13</td><td nowrap="nowrap">[project]</td></tr>
#             <tr><td class="diff_next"><a href="#difflib_chg_to4__2">n</a></td><td class="diff_header" id="from4_13">13</td><td nowrap="nowrap">name&nbsp;=&nbsp;"myproject"&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;#&nbsp;CHANGE&nbsp;ME</td><td class="diff_next"><a href="#difflib_chg_to4__2">n</a></td><td class="diff_header" id="to4_14">14</td><td nowrap="nowrap">name&nbsp;=&nbsp;"myproject"&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<span class="diff_add">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</span>#&nbsp;CHANGE&nbsp;ME</td></tr>
#             <tr><td class="diff_next" id="difflib_chg_to4__2"></td><td class="diff_header" id="from4_14">14</td><td nowrap="nowrap"><span class="diff_sub">dynamic&nbsp;=&nbsp;["version",&nbsp;"readme"]</span></td><td class="diff_next"></td><td class="diff_header" id="to4_15">15</td><td nowrap="nowrap"><span class="diff_add">version&nbsp;=&nbsp;"0.1.0"&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;#&nbsp;static&nbsp;version&nbsp;(or&nbsp;use&nbsp;dynamic&nbsp;below)</span></td></tr>
#             <tr><td class="diff_next"></td><td class="diff_header" id="from4_15">15</td><td nowrap="nowrap">description&nbsp;=&nbsp;"Short&nbsp;description<span class="diff_sub">&nbsp;of&nbsp;your&nbsp;project</span>."&nbsp;&nbsp;<span class="diff_sub">&nbsp;</span>#&nbsp;CHANGE&nbsp;ME</td><td class="diff_next"></td><td class="diff_header" id="to4_16">16</td><td nowrap="nowrap">description&nbsp;=&nbsp;"Short<span class="diff_add">&nbsp;project</span>&nbsp;description."&nbsp;&nbsp;#&nbsp;CHANGE&nbsp;ME</td></tr>
#             <tr><td class="diff_next" id="difflib_chg_to4__3"></td><td class="diff_header"></td><td nowrap="nowrap"></td><td class="diff_next"></td><td class="diff_header" id="to4_17">17</td><td nowrap="nowrap"><span class="diff_add">readme&nbsp;=&nbsp;"README.md"</span></td></tr>
#             <tr><td class="diff_next"></td><td class="diff_header"></td><td nowrap="nowrap"></td><td class="diff_next"></td><td class="diff_header" id="to4_18">18</td><td nowrap="nowrap"><span class="diff_add">license&nbsp;=&nbsp;{&nbsp;text&nbsp;=&nbsp;"MIT"&nbsp;}&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;#&nbsp;CHANGE&nbsp;ME&nbsp;if&nbsp;needed</span></td></tr>
#             <tr><td class="diff_next" id="difflib_chg_to4__4"></td><td class="diff_header" id="from4_16">16</td><td nowrap="nowrap">authors&nbsp;=&nbsp;[{&nbsp;name&nbsp;=&nbsp;"Your&nbsp;Name",&nbsp;email&nbsp;=&nbsp;"you@example.com"&nbsp;}]&nbsp;&nbsp;#&nbsp;CHANGE&nbsp;ME</td><td class="diff_next"></td><td class="diff_header" id="to4_19">19</td><td nowrap="nowrap">authors&nbsp;=&nbsp;[{&nbsp;name&nbsp;=&nbsp;"Your&nbsp;Name",&nbsp;email&nbsp;=&nbsp;"you@example.com"&nbsp;}]&nbsp;&nbsp;#&nbsp;CHANGE&nbsp;ME</td></tr>
#             <tr><td class="diff_next"><a href="#difflib_chg_to4__3">n</a></td><td class="diff_header" id="from4_17">17</td><td nowrap="nowrap"><span class="diff_sub">license&nbsp;=&nbsp;{&nbsp;text&nbsp;=&nbsp;"MIT"&nbsp;}&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;#&nbsp;CHANGE&nbsp;ME&nbsp;if&nbsp;needed</span></td><td class="diff_next"><a href="#difflib_chg_to4__3">n</a></td><td class="diff_header"></td><td nowrap="nowrap"></
