# %%
import home

# %% [markdown]
# ### Directory
#
# ### Text
#
#     * `.txt`
#
# #### Headers
#
#     * `.h`
#     * `.hpp`
#
# #### Source Code
#
#     * `.c`
#     * `.cpp`
#     * `.js`
#     * `.py`
#     * `.sh`
#
# #### HTML
#
#     * `.htm`
#     * `.html`
#
# #### Configuration
#
#     * `.cfg`
#
# #### CSV
#
#     * `.csv`
#
# #### Data
#
#     * `.json`
#
# #### Logs
#
#     * `.log`
#
# #### Stylesheets
#
#     * `.css`
#
# #### CGI
#
#     * `.cgi`
#
# ### Binary
#
# #### Executables
#
# #### Archives
#
#     * `.deb`
#     * `.pkl`
#     * `.tar.gz`
#     * `.zip`
#
# #### Graphics
#
#     * `.gif`
#     * `.jpeg`
#     * `.png`
#
# #### Audio
#
#     * `.flac`
#     * `.mp3`
#
# #### Video
#
#     * `.mp4`
#
# ### Databases
#
#     * `.db`
#
# ### FIFO
#
# ### Links
#
# #### Hard
# #### Symbolic
