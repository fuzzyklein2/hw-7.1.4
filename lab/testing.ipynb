# %% [markdown]
# # Testing

# %%
import subprocess

# %%
import home

# %%
OPTIONS = {
    # "capture_output" : True,
    "encoding" : "utf-8",
    "stdout" : subprocess.PIPE,
    "stderr" : subprocess.PIPE
}
result = subprocess.run([
    "hello"
    ],
        **OPTIONS
    )
print("stdout: ", repr(result.stdout))
print("stderr: ", repr(result.stderr))

# %%
from tools.nbtools import cd, find_proj_root

# %%
find_proj_root()

# %%
import sys
print(sys.executable)

# %%
import sys
print("\n".join(sys.path))

# %%
from os import chdir
chdir('../')
import tools
