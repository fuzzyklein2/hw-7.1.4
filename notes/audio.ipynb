# %% [markdown]
# # Audio
# Play sound files.

# %% [markdown]
# [`miniaudio.h` Documentation](https://miniaud.io/docs/manual/)

# %% [markdown]
# `play_audio` calls `player.play`.
#
# `player.play` just sets `p.playing` to `true`.
